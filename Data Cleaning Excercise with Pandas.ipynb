# %%
import pandas as pd

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
df = pd.read_csv('https://raw.githubusercontent.com/edlich/eternalrepo/master/DS-WAHLFACH/dsm-beuth-edl-demodata-dirty.csv')

# %%
df
# Out:
#       id              full_name  first_name    last_name  \
# 0    1.0        Mariel Finnigan      Mariel     Finnigan
# 1    2.0          Kenyon Possek      Kenyon       Possek
# 2    3.0         Lalo Manifould        Lalo    Manifould
# 3    4.0         Nickola Carous     Nickola       Carous
# 4    5.0          Norman Dubbin      Norman       Dubbin
# 5    6.0           Hasty Perdue       Hasty       Perdue
# 6    7.0         Franz Castello       Franz     Castello
# 7    8.0           Jorge Tarney       Jorge       Tarney
# 8    9.0     Eunice Blakebrough      Eunice  Blakebrough
# 9   10.0  Kristopher Frankcombe  Kristopher   Frankcombe
# 10  11.0           Palm Domotor        Palm      Domotor
# 11  12.0          Luz Lansdowne         Luz    Lansdowne
# 12  13.0         Modestia Keble    Modestia        Keble
# 13  14.0           Stacee Bovis      Stacee        Bovis
# 14  15.0              Eden Wace        Eden         Wace
# ...

# %%
df2 = df.drop(df.index[[17,22]]) # we see that row 17 and 22 do not have any values -> drop them

# %%
df2
# Out:
#       id              full_name  first_name    last_name  \
# 0    1.0        Mariel Finnigan      Mariel     Finnigan
# 1    2.0          Kenyon Possek      Kenyon       Possek
# 2    3.0         Lalo Manifould        Lalo    Manifould
# 3    4.0         Nickola Carous     Nickola       Carous
# 4    5.0          Norman Dubbin      Norman       Dubbin
# 5    6.0           Hasty Perdue       Hasty       Perdue
# 6    7.0         Franz Castello       Franz     Castello
# 7    8.0           Jorge Tarney       Jorge       Tarney
# 8    9.0     Eunice Blakebrough      Eunice  Blakebrough
# 9   10.0  Kristopher Frankcombe  Kristopher   Frankcombe
# 10  11.0           Palm Domotor        Palm      Domotor
# 11  12.0          Luz Lansdowne         Luz    Lansdowne
# 12  13.0         Modestia Keble    Modestia        Keble
# 13  14.0           Stacee Bovis      Stacee        Bovis
# 14  15.0              Eden Wace        Eden         Wace
# ...

# %%
df2.isnull().sum().sum() # total number of NaN values
# Out:
# 3

# %%
df2.isnull().sum() # how many NaN do we have in each columns
# Out:
# id            1
# full_name     0
# first_name    0
# last_name     0
# email         1
# gender        1
# age           0
# dtype: int64

# %%
df2['gender'][5] = 'Male' # the name first_name Hasty let's us assume that it is a male
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2
# Out:
#       id              full_name  first_name    last_name  \
# 0    1.0        Mariel Finnigan      Mariel     Finnigan
# 1    2.0          Kenyon Possek      Kenyon       Possek
# 2    3.0         Lalo Manifould        Lalo    Manifould
# 3    4.0         Nickola Carous     Nickola       Carous
# 4    5.0          Norman Dubbin      Norman       Dubbin
# 5    6.0           Hasty Perdue       Hasty       Perdue
# 6    7.0         Franz Castello       Franz     Castello
# 7    8.0           Jorge Tarney       Jorge       Tarney
# 8    9.0     Eunice Blakebrough      Eunice  Blakebrough
# 9   10.0  Kristopher Frankcombe  Kristopher   Frankcombe
# 10  11.0           Palm Domotor        Palm      Domotor
# 11  12.0          Luz Lansdowne         Luz    Lansdowne
# 12  13.0         Modestia Keble    Modestia        Keble
# 13  14.0           Stacee Bovis      Stacee        Bovis
# 14  15.0              Eden Wace        Eden         Wace
# ...

# %%
 df2.isnull().sum() # how many NaN do we have in each columns left
# Out:
# id            1
# full_name     0
# first_name    0
# last_name     0
# email         1
# gender        0
# age           0
# dtype: int64

# %%
# what to do with missing mail

# %%
df2 = df2.drop(df2.index[[14]]) # drop one Eden Wace since it is a duplicate row

# %%
df2
# Out:
#       id              full_name  first_name    last_name  \
# 0    1.0        Mariel Finnigan      Mariel     Finnigan
# 1    2.0          Kenyon Possek      Kenyon       Possek
# 2    3.0         Lalo Manifould        Lalo    Manifould
# 3    4.0         Nickola Carous     Nickola       Carous
# 4    5.0          Norman Dubbin      Norman       Dubbin
# 5    6.0           Hasty Perdue       Hasty       Perdue
# 6    7.0         Franz Castello       Franz     Castello
# 7    8.0           Jorge Tarney       Jorge       Tarney
# 8    9.0     Eunice Blakebrough      Eunice  Blakebrough
# 9   10.0  Kristopher Frankcombe  Kristopher   Frankcombe
# 10  11.0           Palm Domotor        Palm      Domotor
# 11  12.0          Luz Lansdowne         Luz    Lansdowne
# 12  13.0         Modestia Keble    Modestia        Keble
# 13  14.0           Stacee Bovis      Stacee        Bovis
# 15  16.0              Eden Wace        Eden         Wace
# ...

# %%
df2 = df2.reset_index(drop=True)

# %%
df2
# Out:
#       id              full_name  first_name    last_name  \
# 0    1.0        Mariel Finnigan      Mariel     Finnigan
# 1    2.0          Kenyon Possek      Kenyon       Possek
# 2    3.0         Lalo Manifould        Lalo    Manifould
# 3    4.0         Nickola Carous     Nickola       Carous
# 4    5.0          Norman Dubbin      Norman       Dubbin
# 5    6.0           Hasty Perdue       Hasty       Perdue
# 6    7.0         Franz Castello       Franz     Castello
# 7    8.0           Jorge Tarney       Jorge       Tarney
# 8    9.0     Eunice Blakebrough      Eunice  Blakebrough
# 9   10.0  Kristopher Frankcombe  Kristopher   Frankcombe
# 10  11.0           Palm Domotor        Palm      Domotor
# 11  12.0          Luz Lansdowne         Luz    Lansdowne
# 12  13.0         Modestia Keble    Modestia        Keble
# 13  14.0           Stacee Bovis      Stacee        Bovis
# 14  16.0              Eden Wace        Eden         Wace
# ...

# %%
df2['id'] = df2.index + 1

# %%
df2
# Out:
#     id              full_name  first_name    last_name  \
# 0    1        Mariel Finnigan      Mariel     Finnigan
# 1    2          Kenyon Possek      Kenyon       Possek
# 2    3         Lalo Manifould        Lalo    Manifould
# 3    4         Nickola Carous     Nickola       Carous
# 4    5          Norman Dubbin      Norman       Dubbin
# 5    6           Hasty Perdue       Hasty       Perdue
# 6    7         Franz Castello       Franz     Castello
# 7    8           Jorge Tarney       Jorge       Tarney
# 8    9     Eunice Blakebrough      Eunice  Blakebrough
# 9   10  Kristopher Frankcombe  Kristopher   Frankcombe
# 10  11           Palm Domotor        Palm      Domotor
# 11  12          Luz Lansdowne         Luz    Lansdowne
# 12  13         Modestia Keble    Modestia        Keble
# 13  14           Stacee Bovis      Stacee        Bovis
# 14  15              Eden Wace        Eden         Wace
# 15  16        Tobias Sherburn      Tobias     Sherburn
# ...

# %%
df2.dtypes # check types of columns
# Out:
# id             int64
# full_name     object
# first_name    object
# last_name     object
# email         object
# gender        object
# age           object
# dtype: object

# %%
df2['age'][9] = 0 # set to number, we will set it later
df2
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#     id              full_name  first_name    last_name  \
# 0    1        Mariel Finnigan      Mariel     Finnigan
# 1    2          Kenyon Possek      Kenyon       Possek
# 2    3         Lalo Manifould        Lalo    Manifould
# 3    4         Nickola Carous     Nickola       Carous
# 4    5          Norman Dubbin      Norman       Dubbin
# 5    6           Hasty Perdue       Hasty       Perdue
# 6    7         Franz Castello       Franz     Castello
# 7    8           Jorge Tarney       Jorge       Tarney
# 8    9     Eunice Blakebrough      Eunice  Blakebrough
# ...

# %%
df2[['id','age']] = df2[['id','age']].apply(pd.to_numeric) # change id and age to numeric
df2['age'] = df2['age'].abs() # to get rid of the negative age
df2
# Out:
#     id              full_name  first_name    last_name  \
# 0    1        Mariel Finnigan      Mariel     Finnigan
# 1    2          Kenyon Possek      Kenyon       Possek
# 2    3         Lalo Manifould        Lalo    Manifould
# 3    4         Nickola Carous     Nickola       Carous
# 4    5          Norman Dubbin      Norman       Dubbin
# 5    6           Hasty Perdue       Hasty       Perdue
# 6    7         Franz Castello       Franz     Castello
# 7    8           Jorge Tarney       Jorge       Tarney
# 8    9     Eunice Blakebrough      Eunice  Blakebrough
# 9   10  Kristopher Frankcombe  Kristopher   Frankcombe
# 10  11           Palm Domotor        Palm      Domotor
# 11  12          Luz Lansdowne         Luz    Lansdowne
# 12  13         Modestia Keble    Modestia        Keble
# 13  14           Stacee Bovis      Stacee        Bovis
# 14  15              Eden Wace        Eden         Wace
# 15  16        Tobias Sherburn      Tobias     Sherburn
# ...

# %%
df2['age'][9] = df2['age'].where(df2['age'] >  75).mean() # assign average of 'old' (here older than 75)
df2
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#     id              full_name  first_name    last_name  \
# 0    1        Mariel Finnigan      Mariel     Finnigan
# 1    2          Kenyon Possek      Kenyon       Possek
# 2    3         Lalo Manifould        Lalo    Manifould
# 3    4         Nickola Carous     Nickola       Carous
# 4    5          Norman Dubbin      Norman       Dubbin
# 5    6           Hasty Perdue       Hasty       Perdue
# 6    7         Franz Castello       Franz     Castello
# 7    8           Jorge Tarney       Jorge       Tarney
# 8    9     Eunice Blakebrough      Eunice  Blakebrough
# ...

# %%
# Kerianne Goacher still has no email
# (1) drop the row and reindex again (see above)
# (2) set an email we are not sure about if it'S correct - but we could use the data for some use cases
# (3) keep as is becaue it might not have been collected or she does not have an email
